# %%
from torchvision import transforms
from torch.utils.data import Dataset
from torchvision import  transforms, datasets
from PIL import Image

class MyDataset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __getitem__(self, index):
        x, y = self.subset[index]
        if self.transform:
            x = self.transform(x)
        return x, y

    def __len__(self):
        return len(self.subset)

def check_Image(path):
  try:
    im = Image.open(path)
    im.load()
    return True
  except Exception as e:
    print(f"image path {path} is checked as invalid", str(e))
    return False

# function to creating dataloader
def load_data(data_dir,batch_size=32, num_workers=2 ):

    data_transforms = {

        'train': transforms.Compose([
            transforms.RandomResizedCrop(224),

            transforms.RandomHorizontalFlip(),
            # transforms.ColorJitter(),
            transforms.RandomRotation(15),
            transforms.Pad(10),
            transforms.RandomVerticalFlip(),
            transforms.GaussianBlur(3),

            # transfroms.RandomAdjustSharpness(),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ]),
        'val': transforms.Compose([
            transforms.Resize(224),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ])

    }


    ## for trainval folder

    # image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
    #                                           data_transforms[x])
    #                   for x in ['train', 'val']}

    # class_names = image_datasets['train'].classes
    #_________________________________________________________________

    # for mycati folder

    image_datasets = {}
    all_dataset = datasets.ImageFolder(data_dir,is_valid_file=check_Image)
    train_size = int(0.8 * len(all_dataset))
    test_size = len(all_dataset) - train_size
    image_datasets["train"], image_datasets["val"] = torch.utils.data.random_split(all_dataset, [train_size, test_size])

    image_datasets["train"] = MyDataset(image_datasets["train"],data_transforms["train"])

    image_datasets["val"] = MyDataset(image_datasets["val"],data_transforms["val"])
    class_names = all_dataset.classes

    dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=batch_size,
                                                shuffle=True, num_workers=num_workers)
                for x in ['train', 'val']}
    dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val']}
    return dataloaders, class_names, dataset_sizes

# %%
import matplotlib.pyplot as plt
import numpy as np
from itertools import product

## visualizing functions

def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    # plt.figure(figsize=(10,10))
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


def visualize_model(model, dataloaders, class_names, device,num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()
    plt.title("model")

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                label = sorted(class_names)[labels.cpu().data[j]]
                ax.set_title(f'predicted: {class_names[preds[j]]}, label: {label}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)


def compute_confusion_matrix(model, data_loader, device):

    all_targets, all_predictions = [], []
    with torch.no_grad():

        for i, (features, targets) in enumerate(data_loader):

            features = features.to(device)
            targets = targets
            logits = model(features)
            _, predicted_labels = torch.max(logits, 1)
            all_targets.extend(targets.to('cpu'))
            all_predictions.extend(predicted_labels.to('cpu'))

    all_predictions = all_predictions
    all_predictions = np.array(all_predictions)
    all_targets = np.array(all_targets)

    class_labels = np.unique(np.concatenate((all_targets, all_predictions)))
    if class_labels.shape[0] == 1:
        if class_labels[0] != 0:
            class_labels = np.array([0, class_labels[0]])
        else:
            class_labels = np.array([class_labels[0], 1])
    n_labels = class_labels.shape[0]
    lst = []
    z = list(zip(all_targets, all_predictions))
    for combi in product(class_labels, repeat=2):
        lst.append(z.count(combi))
    mat = np.asarray(lst)[:, None].reshape(n_labels, n_labels)
    return mat


def plot_confusion_matrix(conf_mat,
                          hide_spines=False,
                          hide_ticks=False,
                          figsize=None,
                          cmap=None,
                          colorbar=False,
                          show_absolute=True,
                          show_normed=False,
                          class_names=None):

    if not (show_absolute or show_normed):
        raise AssertionError('Both show_absolute and show_normed are False')
    if class_names is not None and len(class_names) != len(conf_mat):
        raise AssertionError('len(class_names) should be equal to number of'
                             'classes in the dataset')

    total_samples = conf_mat.sum(axis=1)[:, np.newaxis]
    normed_conf_mat = conf_mat.astype('float') / total_samples

    fig, ax = plt.subplots(figsize=figsize)
    ax.grid(False)
    if cmap is None:
        cmap = plt.cm.Blues

    if figsize is None:
        figsize = (len(conf_mat)*1.25, len(conf_mat)*1.25)

    if show_normed:
        matshow = ax.matshow(normed_conf_mat, cmap=cmap)
    else:
        matshow = ax.matshow(conf_mat, cmap=cmap)

    if colorbar:
        fig.colorbar(matshow)

    for i in range(conf_mat.shape[0]):
        for j in range(conf_mat.shape[1]):
            cell_text = ""
            if show_absolute:
                cell_text += format(conf_mat[i, j], 'd')
                if show_normed:
                    cell_text += "\n" + '('
                    cell_text += format(normed_conf_mat[i, j], '.2f') + ')'
            else:
                cell_text += format(normed_conf_mat[i, j], '.2f')
            ax.text(x=j,
                    y=i,
                    s=cell_text,
                    va='center',
                    ha='center',
                    color="white" if normed_conf_mat[i, j] > 0.5 else "black")

    if class_names is not None:
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=90)
        plt.yticks(tick_marks, class_names)

    if hide_spines:
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
        ax.spines['left'].set_visible(False)
        ax.spines['bottom'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    if hide_ticks:
        ax.axes.get_yaxis().set_ticks([])
        ax.axes.get_xaxis().set_ticks([])

    plt.xlabel('predicted label')
    plt.ylabel('true label')
    return fig, ax


def plot_train_info(train_info):
    plt.figure(figsize=(20,5))
    plt.subplot(121)
    plt.title("accuracy")
    plt.plot(train_info["accuracy"]["train"],label="Train")
    plt.plot(train_info["accuracy"]["val"],label="Val")
    plt.legend()
    plt.subplot(122)
    plt.title("loss")
    plt.plot(train_info["loss"]["train"],label="Train")
    plt.plot(train_info["loss"]["val"],label="Val")
    plt.legend()

# %%
EPOCHS = 5
save_name = "res_1_ce_sgd_b64_train_val_ilr001"
batch_size = 32


data_dir = "/content/drive/MyDrive/raphcatr"


dataloaders, class_names, dataset_sizes = load_data(data_dir, batch_size)

inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# image path /content/drive/MyDrive/raphcatr/HY/50_HY_Germany_Johannes Lang_2020-01-25_M_50.242999_7.70442_NA_.jpg is checked as invalid broken data stream when reading image file

# %%
# device agnostic code
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Device is {device}")
resnet18 = torchvision.models.resnet18(pretrained=True)
# nofreeze or freeze
for param in resnet18.parameters():
    param.requires_grad = False



# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = resnet18.fc.in_features
resnet18.fc = nn.Linear(num_ftrs, 3)

resnet18 = resnet18.to(device)
# Out:
# Device is cuda:0

# %% [markdown]
# # Applying different cost respect to class ratio

# %%
#Check class distribution
# Initialize a dictionary to store the count of images per class
class_image_count = {class_name: 0 for class_name in class_names}

# Iterate through the training data loader
for inputs, labels in dataloaders['train']:
    for label in labels:
        class_name = class_names[label.item()]
        class_image_count[class_name] += 1

# Print the count of images per class
for class_name, count in class_image_count.items():
    print(f"Class '{class_name}' has {count} images.")
# Out:
# Class 'DC' has 148 images.
# Class 'HY' has 160 images.
# Class 'WC' has 281 images.

# %%
#Based on class
class_weights = torch.FloatTensor([1./148, 1./160, 1./281])*100
class_weights
# Out:
# tensor([0.6757, 0.6250, 0.3559])

# %%
from torch import optim

# defining loss and optimizer
criterion = nn.CrossEntropyLoss(weight = class_weights).to(device)
optimizer_conv = optim.SGD(resnet18.fc.parameters(), lr=0.01, momentum=0.9)
# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=20, gamma=1, verbose=True)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.

# %%
def train_model(model, criterion, optimizer, scheduler, dataloaders, dataset_sizes, device, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    train_info = {"loss":{}, "accuracy":{}}
    loss_lists = {x: list() for x in ["train","val"]}
    acc_lists = {x:list() for x in ["train","val"]}

    for epoch in range(num_epochs):
        print(f'Epoch {epoch}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]



            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')
            loss_lists[phase].append(epoch_loss)
            acc_lists[phase].append(epoch_acc.item())

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    train_info["loss"].update(loss_lists)
    train_info["accuracy"].update(acc_lists)
    return model, train_info

# %%
model_conv_resnet, resnet_train_info = train_model(resnet18, criterion, optimizer_conv,
                         exp_lr_scheduler,dataloaders,dataset_sizes,device, num_epochs=50)
# Out:
# Epoch 0/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.7597 Acc: 0.6672
# val Loss: 1.9646 Acc: 0.6622
#
# Epoch 1/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.0351 Acc: 0.5603
# val Loss: 1.8734 Acc: 0.6081
#
# Epoch 2/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.0749 Acc: 0.6078
# val Loss: 2.0181 Acc: 0.5743
#
# Epoch 3/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9908 Acc: 0.5993
# val Loss: 1.5817 Acc: 0.7230
#
# Epoch 4/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.8788 Acc: 0.6401
# val Loss: 2.0219 Acc: 0.7095
#
# Epoch 5/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.0067 Acc: 0.6180
# val Loss: 1.5689 Acc: 0.6216
#
# Epoch 6/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.0889 Acc: 0.5772
# val Loss: 1.3487 Acc: 0.6554
#
# Epoch 7/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1121 Acc: 0.6180
# val Loss: 1.3908 Acc: 0.6689
#
# Epoch 8/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9516 Acc: 0.6418
# val Loss: 2.1281 Acc: 0.6351
#
# Epoch 9/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1670 Acc: 0.5620
# val Loss: 1.1938 Acc: 0.7230
#
# Epoch 10/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.8529 Acc: 0.6672
# val Loss: 1.4776 Acc: 0.6486
#
# Epoch 11/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9357 Acc: 0.6316
# val Loss: 0.9332 Acc: 0.6486
#
# Epoch 12/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.6666 Acc: 0.5518
# val Loss: 1.0785 Acc: 0.6081
#
# Epoch 13/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.3735 Acc: 0.5789
# val Loss: 1.5575 Acc: 0.5676
#
# Epoch 14/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.3700 Acc: 0.6129
# val Loss: 2.2853 Acc: 0.7095
#
# Epoch 15/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1785 Acc: 0.6214
# val Loss: 1.9185 Acc: 0.5270
#
# Epoch 16/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1250 Acc: 0.6282
# val Loss: 1.8414 Acc: 0.7432
#
# Epoch 17/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.4041 Acc: 0.5620
# val Loss: 1.7343 Acc: 0.6892
#
# Epoch 18/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1813 Acc: 0.6537
# val Loss: 1.0268 Acc: 0.6486
#
# Epoch 19/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.2881 Acc: 0.6418
# val Loss: 3.1767 Acc: 0.4865
#
# Epoch 20/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.2130 Acc: 0.6112
# val Loss: 1.7764 Acc: 0.7230
#
# Epoch 21/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.2127 Acc: 0.5789
# val Loss: 0.9275 Acc: 0.7027
#
# Epoch 22/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9191 Acc: 0.6553
# val Loss: 1.8942 Acc: 0.6149
#
# Epoch 23/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.0846 Acc: 0.6027
# val Loss: 3.0033 Acc: 0.5541
#
# Epoch 24/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9587 Acc: 0.6231
# val Loss: 1.6567 Acc: 0.6959
#
# Epoch 25/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9524 Acc: 0.6299
# val Loss: 1.1868 Acc: 0.6554
#
# Epoch 26/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9288 Acc: 0.6503
# val Loss: 1.8700 Acc: 0.6014
#
# Epoch 27/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9627 Acc: 0.6553
# val Loss: 2.0909 Acc: 0.5676
#
# Epoch 28/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9538 Acc: 0.6401
# val Loss: 1.4993 Acc: 0.6892
#
# Epoch 29/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9259 Acc: 0.6367
# val Loss: 1.7633 Acc: 0.6959
#
# Epoch 30/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.8446 Acc: 0.6655
# val Loss: 1.3863 Acc: 0.7365
#
# Epoch 31/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.0706 Acc: 0.6384
# val Loss: 1.1844 Acc: 0.6486
#
# Epoch 32/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1933 Acc: 0.5840
# val Loss: 1.2380 Acc: 0.7027
#
# Epoch 33/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1869 Acc: 0.5976
# val Loss: 1.5071 Acc: 0.7500
#
# Epoch 34/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1075 Acc: 0.6248
# val Loss: 2.6152 Acc: 0.4932
#
# Epoch 35/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.3264 Acc: 0.5840
# val Loss: 2.5932 Acc: 0.6216
#
# Epoch 36/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9823 Acc: 0.6418
# val Loss: 1.7078 Acc: 0.5878
#
# Epoch 37/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1853 Acc: 0.6163
# val Loss: 2.0262 Acc: 0.6622
#
# Epoch 38/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1946 Acc: 0.6214
# val Loss: 1.2795 Acc: 0.6351
#
# Epoch 39/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.2687 Acc: 0.6061
# val Loss: 2.1098 Acc: 0.6959
#
# Epoch 40/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9337 Acc: 0.6537
# val Loss: 1.1918 Acc: 0.6892
#
# Epoch 41/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9097 Acc: 0.6553
# val Loss: 1.0704 Acc: 0.6149
#
# Epoch 42/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9803 Acc: 0.6587
# val Loss: 1.0381 Acc: 0.6959
#
# Epoch 43/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.8538 Acc: 0.6757
# val Loss: 1.4347 Acc: 0.6622
#
# Epoch 44/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.0011 Acc: 0.6248
# val Loss: 2.1622 Acc: 0.5068
#
# Epoch 45/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9517 Acc: 0.6740
# val Loss: 1.5023 Acc: 0.5608
#
# Epoch 46/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.8096 Acc: 0.6689
# val Loss: 1.5568 Acc: 0.7365
#
# Epoch 47/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.0475 Acc: 0.6333
# val Loss: 0.9067 Acc: 0.6554
#
# Epoch 48/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.9972 Acc: 0.6418
# val Loss: 0.9428 Acc: 0.6486
#
# Epoch 49/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 0.8355 Acc: 0.6808
# val Loss: 1.7290 Acc: 0.6622
#
# Training complete in 70m 22s
# Best val Acc: 0.750000

# %%
# !mkdir res

# %%
def plot_train_info(train_info):
    plt.figure(figsize=(20,5))
    plt.subplot(121)
    plt.title("accuracy")
    plt.plot(train_info["accuracy"]["train"],label="Train")
    plt.plot(train_info["accuracy"]["val"],label="Val")
    plt.legend()
    plt.subplot(122)
    plt.title("loss")
    plt.plot(train_info["loss"]["train"],label="Train")
    plt.plot(train_info["loss"]["val"],label="Val")
    plt.legend()

# %%
# print(train_info)
save_name = "res_18_cost_sensitive"
plot_train_info(resnet_train_info)
plt.savefig(f"res/{save_name}.eps")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
class_dict = {0:'DC', 1:'HY', 2:'WC'}
mat = compute_confusion_matrix(model=model_conv_resnet, data_loader=dataloaders['val'], device=torch.device('cuda'))
plot_confusion_matrix(mat, class_names=class_dict.values())
plt.savefig(f'res/{save_name}_confusion_cost_sensitive.png')
plt.show()

# %% [markdown]
# # VGG16

# %%
import torch
import torch.nn as nn
import torchvision

# Check if GPU is available and set device accordingly
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Device is {device}")

# Load pre-trained VGG16 model
vgg16 = torchvision.models.vgg16(pretrained=True)

# Freeze or unfreeze layers based on your requirement
for param in vgg16.parameters():
    param.requires_grad = False

# Modify the fully connected layer for the number of classes in your specific task
num_ftrs = vgg16.classifier[6].in_features
vgg16.classifier[6] = nn.Linear(num_ftrs, 3)  # Assuming 3 classes, modify accordingly

# Move the model to the specified device
vgg16 = vgg16.to(device)

# Print the modified VGG16 model
print(vgg16)
# Out:
# Device is cuda:0
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:09<00:00, 55.7MB/s]
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=3, bias=True)
#   )
# )

# %%
from torch import optim

# defining loss and optimizer
criterion = nn.CrossEntropyLoss(weight = class_weights).to(device)

optimizer = optim.SGD(vgg16.parameters(), lr=0.01, momentum=0.9)

# Example: StepLR scheduler
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=20, gamma=1, verbose=True)
# Out:
# Adjusting learning rate of group 0 to 1.0000e-02.

# %%
model_conv_vgg16, vgg16_train_info = train_model(vgg16, criterion, optimizer,
                         exp_lr_scheduler,dataloaders,dataset_sizes,device, num_epochs=50)
# Out:
# Epoch 0/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.1978 Acc: 0.4550
# val Loss: 1.0606 Acc: 0.6554
#
# Epoch 1/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.3368 Acc: 0.5603
# val Loss: 1.2498 Acc: 0.6554
#
# Epoch 2/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.6216 Acc: 0.5314
# val Loss: 1.3496 Acc: 0.6419
#
# Epoch 3/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.4601 Acc: 0.5739
# val Loss: 1.3883 Acc: 0.6419
#
# Epoch 4/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.4972 Acc: 0.5484
# val Loss: 1.4139 Acc: 0.5473
#
# Epoch 5/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.7436 Acc: 0.5654
# val Loss: 1.3862 Acc: 0.6351
#
# Epoch 6/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.6335 Acc: 0.5637
# val Loss: 1.2735 Acc: 0.6284
#
# Epoch 7/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.0116 Acc: 0.5467
# val Loss: 1.2339 Acc: 0.6892
#
# Epoch 8/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.1647 Acc: 0.5484
# val Loss: 2.1970 Acc: 0.6689
#
# Epoch 9/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.3380 Acc: 0.5467
# val Loss: 2.4094 Acc: 0.6149
#
# Epoch 10/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.3275 Acc: 0.5331
# val Loss: 2.3533 Acc: 0.6014
#
# Epoch 11/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.4856 Acc: 0.5789
# val Loss: 2.0487 Acc: 0.5811
#
# Epoch 12/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.6758 Acc: 0.5144
# val Loss: 2.0918 Acc: 0.6419
#
# Epoch 13/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.0195 Acc: 0.5603
# val Loss: 2.0909 Acc: 0.5405
#
# Epoch 14/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.2633 Acc: 0.5789
# val Loss: 1.8214 Acc: 0.6351
#
# Epoch 15/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.2355 Acc: 0.5620
# val Loss: 1.5701 Acc: 0.6149
#
# Epoch 16/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.9045 Acc: 0.5789
# val Loss: 1.9174 Acc: 0.6081
#
# Epoch 17/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.4617 Acc: 0.5382
# val Loss: 1.7668 Acc: 0.6419
#
# Epoch 18/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.5549 Acc: 0.5263
# val Loss: 1.6593 Acc: 0.5811
#
# Epoch 19/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.2170 Acc: 0.5688
# val Loss: 1.6900 Acc: 0.6689
#
# Epoch 20/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.5283 Acc: 0.5552
# val Loss: 2.1863 Acc: 0.5541
#
# Epoch 21/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.4570 Acc: 0.6027
# val Loss: 1.9087 Acc: 0.6351
#
# Epoch 22/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.1204 Acc: 0.5484
# val Loss: 1.7410 Acc: 0.7095
#
# Epoch 23/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.4249 Acc: 0.5637
# val Loss: 1.8161 Acc: 0.6351
#
# Epoch 24/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.5339 Acc: 0.5705
# val Loss: 2.1624 Acc: 0.6081
#
# Epoch 25/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.3421 Acc: 0.5297
# val Loss: 2.2815 Acc: 0.7162
#
# Epoch 26/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.5816 Acc: 0.5586
# val Loss: 1.7586 Acc: 0.5946
#
# Epoch 27/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.3087 Acc: 0.5874
# val Loss: 2.5759 Acc: 0.6892
#
# Epoch 28/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.6171 Acc: 0.5586
# val Loss: 1.5276 Acc: 0.6622
#
# Epoch 29/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.2613 Acc: 0.5705
# val Loss: 1.6067 Acc: 0.7095
#
# Epoch 30/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.6738 Acc: 0.5671
# val Loss: 2.4751 Acc: 0.5270
#
# Epoch 31/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.5210 Acc: 0.5772
# val Loss: 2.0303 Acc: 0.6689
#
# Epoch 32/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.3420 Acc: 0.5620
# val Loss: 2.1312 Acc: 0.6216
#
# Epoch 33/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.3184 Acc: 0.5688
# val Loss: 2.0696 Acc: 0.6554
#
# Epoch 34/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.1698 Acc: 0.5722
# val Loss: 1.7592 Acc: 0.6757
#
# Epoch 35/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.4273 Acc: 0.5399
# val Loss: 2.4782 Acc: 0.5338
#
# Epoch 36/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.3603 Acc: 0.5569
# val Loss: 2.0452 Acc: 0.6284
#
# Epoch 37/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.3292 Acc: 0.5705
# val Loss: 1.5660 Acc: 0.5946
#
# Epoch 38/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.1610 Acc: 0.5501
# val Loss: 1.6211 Acc: 0.6486
#
# Epoch 39/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.1267 Acc: 0.5976
# val Loss: 1.9242 Acc: 0.6216
#
# Epoch 40/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.2300 Acc: 0.5756
# val Loss: 1.7999 Acc: 0.6081
#
# Epoch 41/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.1220 Acc: 0.6044
# val Loss: 1.8929 Acc: 0.5878
#
# Epoch 42/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.3237 Acc: 0.5840
# val Loss: 2.1027 Acc: 0.6149
#
# Epoch 43/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.0567 Acc: 0.5942
# val Loss: 1.6774 Acc: 0.6757
#
# Epoch 44/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.8370 Acc: 0.6469
# val Loss: 1.5023 Acc: 0.6824
#
# Epoch 45/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.1641 Acc: 0.5603
# val Loss: 1.7375 Acc: 0.6284
#
# Epoch 46/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.0107 Acc: 0.5722
# val Loss: 1.7505 Acc: 0.6554
#
# Epoch 47/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.0432 Acc: 0.5874
# val Loss: 2.0804 Acc: 0.5946
#
# Epoch 48/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 1.9251 Acc: 0.5722
# val Loss: 1.8845 Acc: 0.6351
#
# Epoch 49/49
# ----------
# Adjusting learning rate of group 0 to 1.0000e-02.
# train Loss: 2.0736 Acc: 0.6061
# val Loss: 2.0244 Acc: 0.6216
#
# Training complete in 70m 30s
# Best val Acc: 0.716216

# %%
# !mkdir vgg
# Out:
# mkdir: cannot create directory ‘vgg’: File exists

# %%
# print(train_info)
save_name = "vgg_16_cost_sensitive"
plot_train_info(vgg16_train_info)
plt.savefig(f"vgg/{save_name}.eps")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
class_dict = {0:'DC', 1:'HY', 2:'WC'}
mat = compute_confusion_matrix(model=model_conv_vgg16, data_loader=dataloaders['val'], device=torch.device('cuda'))
plot_confusion_matrix(mat, class_names=class_dict.values())
plt.savefig(f'vgg/{save_name}_confusion_cost_sensitive.png')
plt.show()
